# %% [markdown]
# # Create Inputs

# %%
import pandas as pd

# %%
output_path = './data/inputs/samples_mangrove.csv'

# %%
df = pd.DataFrame({
    'latitude': [3.8046593211],
    'longitude': [98.6429308016],
    'year': [2020],
    'date': ['2020-08-15'],
})

df.to_csv(output_path, index=False)
df
# Out:
#    latitude  longitude  year        date
# 0  3.804659  98.642931  2020  2020-08-15
