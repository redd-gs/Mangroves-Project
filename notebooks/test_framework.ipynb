# %% [markdown]
# # Test Framework

# %%
import sys

sys.path.append('../')
from mangroves.scripts.data import MangroveDataset, MangroveDataModule

# %%
path = '../share/data/'
max_samples = 16

dataset = MangroveDataset(
    path=path, 
    train=True, 
    max_samples=max_samples)

print(f'Dataset length: {len(dataset)}')
# Out:
# Dataset length: 16

# %%
datamodule = MangroveDataModule(
    dataset=dataset, 
    batch_size=4)

# %%
datamodule.train_dataset.dataset.data
# Out:
#                      embeddings     ratio  train
# 0   ../share/data//train/00.tif  0.939680      1
# 1   ../share/data//train/01.tif  0.787047      1
# 2   ../share/data//train/02.tif  0.488349      1
# 3   ../share/data//train/03.tif  0.365663      1
# 4   ../share/data//train/04.tif  0.882066      1
# 5   ../share/data//train/05.tif  0.412846      1
# 6   ../share/data//train/06.tif  0.303499      1
# 7   ../share/data//train/07.tif  0.855768      1
# 8   ../share/data//train/08.tif  0.017760      1
# 9   ../share/data//train/09.tif  0.396111      1
# 10  ../share/data//train/10.tif  0.451095      1
# 11  ../share/data//train/11.tif  0.238683      1
# 12  ../share/data//train/12.tif  0.540178      1
# 13  ../share/data//train/13.tif  0.892162      1
# 14  ../share/data//train/14.tif  0.182136      1
# 15  ../share/data//train/15.tif  0.900027      1

# %%
batch = next(iter(datamodule.train_dataloader()))
print(f'Batch shape: {batch[0].shape}, Batch labels: {batch[1]}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 batch = next(iter(datamodule.train_dataloader()))
#       2 print(f'Batch shape: {batch[0].shape}, Batch labels: {batch[1]}')
#
# File ~/miniforge3/envs/mangroves/lib/python3.11/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# ...
